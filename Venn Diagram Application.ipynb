# %%
#Import libraries
from matplotlib_venn import venn2, venn2_circles, venn2_unweighted
from matplotlib_venn import venn3, venn3_circles
from matplotlib import pyplot as plt
# %matplotlib inline


choice=input('enter 2 for two sets and 3 for three sets')
if choice=='2':
    print("the part sahded with  yellow is your answer ")

    set1 = set()
    a=int(input("how many values do you want in set a "))
    for i in range(a):
        b=int(input("enter "+str(i+1)+"  elemnt:  "))
        set1.add(b)
    print(set1)    

    print(set1)
    set2 = set()
    c=int(input("how many values do you want in set b "))
    for i in range(c):
        d=int(input("enter "+str(i+1)+"  elemnt:  "))
        set2.add(d)
    print(set2)   
    result=set1.intersection(set2)
    
    union_of_set_a_and_b = set1.union(set2)
    print('1 for union')
    print('2 for intersection')
    print('3 for a-b')
    print('4 for b-a')
    print("5 to end ")

    # %matplotlib inline
    import matplotlib_venn as vplt 
    from matplotlib import pyplot as plt
    gh=0
    a=set1.difference(set2)
    b=set2.difference(set1)
    c=set1.intersection(set2)
    while(gh!=5):
        gh=int(input("enter your chice"))
        if (gh==1):
            if result==set():

                v = vplt.venn2(subsets={'10': 10, '01':  10, '11': 0}, set_labels = (' ', '  '))


                v.get_patch_by_id('10').set_color('yellow')
                v.get_patch_by_id('01').set_color('yellow')

            else:
                v = vplt.venn2(subsets={'10': 10, '01':  10, '11': 5}, set_labels = (' ', '  '))


                v.get_patch_by_id('10').set_color('yellow')
                v.get_patch_by_id('01').set_color('yellow')
                v.get_patch_by_id('11').set_color('yellow')




        if (gh==2):
            if result==set():

                v = vplt.venn2(subsets={'10': 10, '01':  10, '11': 0}, set_labels = (' ', '  '))


                v.get_patch_by_id('10').set_color('orange')
                v.get_patch_by_id('01').set_color('blue')

            else:
                v = vplt.venn2(subsets={'10': 10, '01':  10, '11': 5}, set_labels = (' ', '  '))


                v.get_patch_by_id('10').set_color('orange')
                v.get_patch_by_id('01').set_color('blue')
                v.get_patch_by_id('11').set_color('yellow')



        if (gh==3):
            if result==set():

                v = vplt.venn2(subsets={'10': 10, '01':  10, '11': 0}, set_labels = (' ', '  '))


                v.get_patch_by_id('10').set_color('yellow')
                v.get_patch_by_id('01').set_color('orange')

            else:
                v = vplt.venn2(subsets={'10': 10, '01':  10, '11': 5}, set_labels = (' ', '  '))


                v.get_patch_by_id('10').set_color('yellow')
                v.get_patch_by_id('01').set_color('orange')
                v.get_patch_by_id('11').set_color('blue')



        if (gh==4):
            if result==set():
                v = vplt.venn2(subsets={'10': 10, '01':  10, '11': 0}, set_labels = (' ', '  '))


                v.get_patch_by_id('10').set_color('blue')
                v.get_patch_by_id('01').set_color('yellow')

            else:
                v = vplt.venn2(subsets={'10': 10, '01':  10, '11': 5}, set_labels = (' ', '  '))


                v.get_patch_by_id('10').set_color('blue')
                v.get_patch_by_id('01').set_color('yellow')
                v.get_patch_by_id('11').set_color('orange')


        if result==set():
            v.get_label_by_id('10').set_text(a)
            v.get_label_by_id('01').set_text(b)
            text.set_fontsize(13)
            plt.show()

        else:
            v.get_label_by_id('10').set_text(a)
            v.get_label_by_id('01').set_text(b)
            v.get_label_by_id('11').set_text(c)
            for text in v.subset_labels:
                text.set_fontsize(13)
            plt.show()





        if (gh==5):
            break   




elif choice=='3':
    set1 = set()
    c=int(input("how many values do you want in set a "))
    for i in range(c):
        d=int(input("enter "+str(i+1)+"  elemnt:  "))
        set1.add(d)
    print(set1)
    set2 = set()
    c=int(input("how many values do you want in set b "))
    for i in range(c):
        d=int(input("enter "+str(i+1)+"  elemnt:  "))
        set2.add(d)
    print(set2)    
    set3 = set()
    c=int(input("how many values do you want in set v "))
    for i in range(c):
        d=int(input("enter "+str(i+1)+"  elemnt:  "))
        set3.add(d)
    print(set3)    
    print('press 1 for A u' +'('+'B u C'+')')
    print('press 2 for A n'+'('+'B n C'+')')
    print('press 3 for (A n B) u C')
    print('press 4 for (A u B) n C')
    print('press 5 for (A u B)', 'n (A u C)')

    a=(set1-set2)-set3
    b=(set2-set1)-set3
    c=(set3-set2)-set1
    mid_of_all=set1.intersection(set2,set3)
    mid_of_a_and_b=(set1.intersection(set2))-mid_of_all
    mid_of_b_and_c=(set2.intersection(set3))-mid_of_all
    mid_of_a_and_c=(set3.intersection(set1))-mid_of_all
    gh=0
    while (gh!=6):
        gh=int(input('enter your choice'))
        if gh==1:
            v3 = venn3(subsets = {'100':30, '010':30, '110':17,
                                  '001':30, '101':17, '011':17, '111':5},
                       set_labels = ('', '', ''))
    #a union b union c
            v3.get_patch_by_id('100').set_color('yellow')
            v3.get_patch_by_id('010').set_color('yellow')
            v3.get_patch_by_id('001').set_color('yellow')
            v3.get_patch_by_id('110').set_color('yellow')
            v3.get_patch_by_id('101').set_color('yellow')
            v3.get_patch_by_id('011').set_color('yellow')
            v3.get_patch_by_id('111').set_color('yellow')




        if gh==2:
            v3 = venn3(subsets = {'100':30, '010':30, '110':17,
                                  '001':30, '101':17, '011':17, '111':5},
                       set_labels = ('', '', ''))
    # a instersection b intersection c
            v3.get_patch_by_id('100').set_color('red')
            v3.get_patch_by_id('010').set_color('grey')
            v3.get_patch_by_id('001').set_color('blue')
            v3.get_patch_by_id('110').set_color('orange')
            v3.get_patch_by_id('101').set_color('purple')
            v3.get_patch_by_id('011').set_color('green')
            v3.get_patch_by_id('111').set_color('yellow')






        if gh==3:
            v3 = venn3(subsets = {'100':30, '010':30, '110':17,
                                  '001':30, '101':17, '011':17, '111':5},
                       set_labels = ('', '', ''))
    # a intersection b union cjmn                        
            v3.get_patch_by_id('100').set_color('red')
            v3.get_patch_by_id('010').set_color('orange')
            v3.get_patch_by_id('001').set_color('yellow')
            v3.get_patch_by_id('110').set_color('yellow')
            v3.get_patch_by_id('101').set_color('yellow')
            v3.get_patch_by_id('011').set_color('yellow')
            v3.get_patch_by_id('111').set_color('yellow')



        if gh==4:
            v3 = venn3(subsets = {'100':30, '010':30, '110':17,
                                  '001':30, '101':17, '011':17, '111':5},
                       set_labels = ('', '', ''))

            v3.get_patch_by_id('100').set_color('red')
            v3.get_patch_by_id('010').set_color('orange')
            v3.get_patch_by_id('001').set_color('blue')
            v3.get_patch_by_id('110').set_color('orange')
            v3.get_patch_by_id('101').set_color('yellow')
            v3.get_patch_by_id('011').set_color('yellow')
            v3.get_patch_by_id('111').set_color('yellow')

        if gh==5:
            v3 = venn3(subsets = {'100':30, '010':30, '110':17,
                                  '001':30, '101':17, '011':17, '111':5},
                       set_labels = ('', '', ''))

            v3.get_patch_by_id('100').set_color('yellow')
            v3.get_patch_by_id('010').set_color('orange')
            v3.get_patch_by_id('001').set_color('blue')
            v3.get_patch_by_id('110').set_color('orange')
            v3.get_patch_by_id('101').set_color('yellow')
            v3.get_patch_by_id('011').set_color('yellow')
            v3.get_patch_by_id('111').set_color('yellow')









        v3.get_label_by_id('100').set_text(a)
        v3.get_label_by_id('010').set_text(b)
        v3.get_label_by_id('001').set_text(c)
        v3.get_label_by_id('110').set_text(mid_of_a_and_b)
        v3.get_label_by_id('101').set_text(mid_of_a_and_c)
        v3.get_label_by_id('011').set_text(mid_of_b_and_c)
        v3.get_label_by_id('111').set_text(mid_of_all)
        for text in v3.subset_labels:
            text.set_fontsize(13)
        plt.show()

        if gh==6:
            break
# Out:
# enter 2 for two sets and 3 for three sets2
# the part sahded with  yellow is your answer
# how many values do you want in set a 2
# enter 1  elemnt:  1
# enter 2  elemnt:  2
# {1, 2}
# {1, 2}
# how many values do you want in set b 2
# enter 1  elemnt:  2
# enter 2  elemnt:  3
# {2, 3}
# 1 for union
# 2 for intersection
# 3 for a-b
# 4 for b-a
# 5 to end
# enter your chice2
